# %% [markdown]
# <a href="https://colab.research.google.com/github/WanyaKruk/DZ-5/blob/main/DZ5_(automl).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 30.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 43.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 65.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import kagglehub

data = kagglehub.dataset_download("debajyotipodder/co2-emission-by-vehicles")
print(data)
# Out:
# /root/.cache/kagglehub/datasets/debajyotipodder/co2-emission-by-vehicles/versions/1

# %%
from pycaret.regression import *
import pandas as pd
data = pd.read_csv('CO2 Emissions_Canada.csv')
s = setup(data, session_id = 123)
# Out:
# <style type="text/css">
# #T_bec7d_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bec7d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bec7d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bec7d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bec7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bec7d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bec7d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_bec7d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bec7d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bec7d_row1_col1" class="data row1 col1" >CO2 Emissions(g/km)</td>
#     </tr>
#     <tr>
#       <th id="T_bec7d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_529a1 th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# LinearRegression(n_jobs=-1)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot = 'feature')

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9d0c3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d0c3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9d0c3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9d0c3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9d0c3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9d0c3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9d0c3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9d0c3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d0c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d0c3_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_9d0c3_row0_col1" class="data row0 col1" >3.1321</td>
# ...

# %%
save_model(best, 'my_best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Engine Size(L)', 'Cylinders',
#                                               'Fuel Consumption City (L/100 km)',
#                                               'Fuel Consumption Hwy (L/100 km)',
#                                               'Fuel Consumption Comb (L/100 km)',
#                                               'Fuel Consumption Comb (mpg)'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Make', 'Model', 'Vehicle Clas...
#                                                                      'Fuel '
#                                                                      'Type'],
#                                                                handle_missing='return_nan',
# ...
